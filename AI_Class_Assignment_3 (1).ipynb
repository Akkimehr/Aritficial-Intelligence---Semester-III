# %%
import networkx as nx

h=nx.complete_graph(10)

nx.draw(h)

# %%
#### IMPLEMENTATION 2

list_1= []
vertices= ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J']

for i in range(len(vertices)):
  current = vertices[i]
  rest = [x for j,x in enumerate(vertices) if j!=i]
  list_1.append([current, rest])

list_1
# Out:
# [['A', ['B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J']],
#  ['B', ['A', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J']],
#  ['C', ['A', 'B', 'D', 'E', 'F', 'G', 'H', 'I', 'J']],
#  ['D', ['A', 'B', 'C', 'E', 'F', 'G', 'H', 'I', 'J']],
#  ['E', ['A', 'B', 'C', 'D', 'F', 'G', 'H', 'I', 'J']],
#  ['F', ['A', 'B', 'C', 'D', 'E', 'G', 'H', 'I', 'J']],
#  ['G', ['A', 'B', 'C', 'D', 'E', 'F', 'H', 'I', 'J']],
#  ['H', ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'I', 'J']],
#  ['I', ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'J']],
#  ['J', ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I']]]

# %%
#### IMPLEMENTATION 3
import numpy as np

list_2= []
vertices= ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J']

for i in range(len(vertices)):
  current = vertices[i]
  rest = [x for j,x in enumerate(vertices) if j!=i]
  rest_new = tuple(rest)
  list_2.append([current, rest_new])

list_2
# Out:
# [['A', ('B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J')],
#  ['B', ('A', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J')],
#  ['C', ('A', 'B', 'D', 'E', 'F', 'G', 'H', 'I', 'J')],
#  ['D', ('A', 'B', 'C', 'E', 'F', 'G', 'H', 'I', 'J')],
#  ['E', ('A', 'B', 'C', 'D', 'F', 'G', 'H', 'I', 'J')],
#  ['F', ('A', 'B', 'C', 'D', 'E', 'G', 'H', 'I', 'J')],
#  ['G', ('A', 'B', 'C', 'D', 'E', 'F', 'H', 'I', 'J')],
#  ['H', ('A', 'B', 'C', 'D', 'E', 'F', 'G', 'I', 'J')],
#  ['I', ('A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'J')],
#  ['J', ('A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I')]]

# %%
#### IMPLEMENTATION 4
tuple_2 = []
vertices= ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J']

for i in range(len(vertices)):
  current = vertices[i]
  rest = [x for j,x in enumerate(vertices) if j!=i]
  rest_new = tuple(rest)
  tuple_2.append([current, rest_new])

tuple_2_new = tuple(tuple_2)
tuple_2_new
# Out:
# (['A', ('B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J')],
#  ['B', ('A', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J')],
#  ['C', ('A', 'B', 'D', 'E', 'F', 'G', 'H', 'I', 'J')],
#  ['D', ('A', 'B', 'C', 'E', 'F', 'G', 'H', 'I', 'J')],
#  ['E', ('A', 'B', 'C', 'D', 'F', 'G', 'H', 'I', 'J')],
#  ['F', ('A', 'B', 'C', 'D', 'E', 'G', 'H', 'I', 'J')],
#  ['G', ('A', 'B', 'C', 'D', 'E', 'F', 'H', 'I', 'J')],
#  ['H', ('A', 'B', 'C', 'D', 'E', 'F', 'G', 'I', 'J')],
#  ['I', ('A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'J')],
#  ['J', ('A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I')])

# %%
#### IMPLEMENTATION 4
dict_1 = {}
vertices= ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J']

for i in range(len(vertices)):
  current = vertices[i]
  rest = [x for j,x in enumerate(vertices) if j!=i]
  dict_1[current] = rest

dict_1
# Out:
# {'A': ['B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J'],
#  'B': ['A', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J'],
#  'C': ['A', 'B', 'D', 'E', 'F', 'G', 'H', 'I', 'J'],
#  'D': ['A', 'B', 'C', 'E', 'F', 'G', 'H', 'I', 'J'],
#  'E': ['A', 'B', 'C', 'D', 'F', 'G', 'H', 'I', 'J'],
#  'F': ['A', 'B', 'C', 'D', 'E', 'G', 'H', 'I', 'J'],
#  'G': ['A', 'B', 'C', 'D', 'E', 'F', 'H', 'I', 'J'],
#  'H': ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'I', 'J'],
#  'I': ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'J'],
#  'J': ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I']}

# %% [markdown]
# ***BINARY TREE IMPLEMENTATION***

# %%
# !pip install binarytree

# %%
from binarytree import bst

root = bst(height=9, is_perfect=True)
# Out:
# Node(511)

# %% [markdown]
# ***DEPTH FIRST SEARCH***

# %%
class Node: 
  def __init__(self, key): 
    self.left = None
    self.right = None
    self.val = key 
  
def print_1(root): 
  if root:
    print_1(root.left) 
    print(root.val), 
    print_1(root.right) 
          
 
root = Node(1) 
root.left = Node(2) 
root.right = Node(3) 
root.left.left = Node(4) 
root.left.right = Node(5) 
root.right.left = Node(6)
root.right.right = Node(7)
root.left.left.left = Node(8)
root.left.left.right = Node(9)
root.left.right.left = Node(10)
root.left.right.right = Node(11)
root.right.left.left = Node(12)
root.right.left.right = Node(13)
root.right.right.left = Node(14)
root.right.right.right = Node(15)

print_1(root.left)
# Out:
# 8
# 4
# 9
# 2
# 10
# 5
# 11

# %%
# Python program to for tree traversals 
  
# A class that represents an individual node in a 
# Binary Tree 
class Node: 
    def __init__(self, key): 
        self.left = None
        self.right = None
        self.val = key 
  
  
# A function to do inorder tree traversal 
def printInorder(root): 
  
    if root: 
  
        # First recur on left child 
        printInorder(root.left) 
  
        # then print the data of node 
        print(root.val), 
  
        # now recur on right child 
        printInorder(root.right) 
          
  
# Driver code 
root = Node(1) 
root.left = Node(2) 
root.right = Node(3) 
root.left.left = Node(4) 
root.left.right = Node(5) 

printInorder(root)
# Out:
# 4
# 2
# 5
# 1
# 3
